# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaveshtarole/Monday-Machine-learning-M2L-/blob/week-1/Numerical_pre_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Collection

# %%
dia_data = pd.read_csv('/content/diabetes.csv')

# %%
dia_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
dia_data.shape
# Out:
# (768, 9)

# %%
dia_data.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# Separsting features and targets

# %%
x = dia_data.drop(columns='Outcome', axis= 1)
y = dia_data['Outcome']

# %%
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data standerdization

# %%
scaler = StandardScaler()
standerd_data = scaler.fit_transform(x)

# %%
x = standerd_data

# %%
print(x)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Spliting the dataset into training and testing

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size= 0.2, random_state= 2)

# %%
print(x_train)
# Out:
# [[-0.84488505  0.09719231  0.25303625 ... -0.53211885 -1.12311057
#   -0.27575966]
#  [-0.84488505 -0.81042491  0.66661825 ...  0.38169971 -0.72143478
#    0.83038113]
#  [-1.14185152 -0.84172205  0.04624525 ...  1.4605133  -0.37714125
#   -1.04154944]
#  ...
#  [ 0.04601433  0.12848945  0.04624525 ... -0.39250768  2.02989333
#    1.00055664]
#  [-0.25095213 -0.15318486  0.25303625 ... -0.72249772 -1.10196973
#   -0.78628618]
#  [ 0.04601433 -0.34096773 -0.16054575 ... -0.01174995 -0.00264654
#   -0.36084741]]

# %%
print(x_test)
# Out:
# [[-0.54791859 -1.02950492  0.25303625 ... -0.37981576 -0.73351526
#   -0.95646168]
#  [-0.54791859  0.25367803  0.77001375 ... -0.506735   -0.56740873
#   -0.53102292]
#  [-1.14185152 -0.59134489  0.45982725 ...  0.31824009 -0.70633419
#   -0.78628618]
#  ...
#  [-1.14185152  0.34756947  0.45982725 ...  0.05170968 -0.23821579
#   -1.04154944]
#  [ 0.3429808   0.5040552   2.01075975 ...  2.1331853  -0.73955549
#    0.31985461]
#  [-0.84488505 -1.4989621  -0.98770975 ... -1.14133123 -0.676133
#   -1.04154944]]

# %%
print(y_train)
# Out:
# 602    0
# 429    1
# 623    0
# 209    1
# 589    0
#       ..
# 534    0
# 584    1
# 493    1
# 527    0
# 168    0
# Name: Outcome, Length: 614, dtype: int64

# %%
print(y_test)
# Out:
# 158    0
# 251    0
# 631    0
# 757    1
# 689    1
#       ..
# 733    0
# 441    0
# 627    0
# 84     1
# 55     0
# Name: Outcome, Length: 154, dtype: int64

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)
